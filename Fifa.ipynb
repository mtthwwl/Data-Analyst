# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
fifa = pd.read_csv("/content/drive/MyDrive/Dataset/players_20.csv")
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
for col in fifa.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa['nationality'].value_counts()
# Out:
# nationality
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: count, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts().head()
# Out:
# nationality
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: count, dtype: int64

# %%
students_country = (fifa['nationality'] == 'India').value_counts()
print(students_country)
# Out:
# nationality
# False    18255
# True        23
# Name: count, dtype: int64

# %%
fifa[fifa['nationality'] == 'India'].head()
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13102     251723  https://sofifa.com/player/251723/prakul-bhatt/...
# 13103     251728  https://sofifa.com/player/251728/bhadrashree-r...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 13971     251727  https://sofifa.com/player/251727/hantidev-bhan...
#
#            short_name             long_name  age         dob  height_cm  \
# 12155   G. Chatterjee   Gajodara Chatterjee   33  1985-07-04        195
# 13102        P. Bhatt          Prakul Bhatt   34  1985-04-07        182
# 13103          B. Raj       Bhadrashree Raj   31  1988-03-25        175
# 13970  A. Chakraborty  Abhimoda Chakraborty   33  1985-10-27        189
# 13971     H. Bhandari     Hantidev Bhandari   30  1989-06-22        178
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
fifa.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 7     203376  https://sofifa.com/player/203376/virgil-van-di...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...

# %%
fifa['nationality'].value_counts()[0: 10]
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: count, dtype: int64

# %%
fifa["nationality"].value_counts()[0:5].keys()
plt.figure(figsize = (8, 5))
plt.bar(list(fifa["nationality"].value_counts()[0:5].keys()), list(fifa["nationality"].value_counts()[0:5]), color = ["cyan", "orange", "brown", "grey", "yellow"] )
plt.show()

# %%
player_salary = fifa[['short_name', 'wage_eur']]
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary = player_salary.sort_values(by = 'wage_eur', ascending = False)
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize = (8, 5))
plt.bar(list(player_salary['short_name'][0:5]), list(player_salary['wage_eur'][0:5]), color = "r")
plt.show()

# %%
germany = fifa[fifa['nationality'] == 'Germany']
germany
# Out:
#        sofifa_id                                         player_url  \
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# 31        167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37        188350  https://sofifa.com/player/188350/marco-reus/20...
# 49        178603  https://sofifa.com/player/178603/mats-hummels/...
# ...          ...                                                ...
# 18123     252076  https://sofifa.com/player/252076/lukas-schelle...
# 18156     251856  https://sofifa.com/player/251856/dominik-meise...
# 18186     243537  https://sofifa.com/player/243537/maximilian-br...
# 18191     244043  https://sofifa.com/player/244043/nico-stephan/...
# 18197     244172  https://sofifa.com/player/244172/matthis-harsm...
#
#             short_name              long_name  age         dob  height_cm  \
# 6        M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# ...

# %%
# Short by height
germany.sort_values(by = 'height_cm', ascending = False)
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# ...          ...                                                ...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 6364      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 15960     247284  https://sofifa.com/player/247284/patrick-finge...
# 11380     250936  https://sofifa.com/player/250936/seref-ozcan/2...
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# ...

# %%
# Sort by weight
germany.sort_values(by = 'weight_kg', ascending = False)
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# ...          ...                                                ...
# 17276     248583  https://sofifa.com/player/248583/sinisa-spreca...
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
# 13387     252559  https://sofifa.com/player/252559/volkan-egri/2...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 17879     244094  https://sofifa.com/player/244094/leonard-langh...
#
#            short_name           long_name  age         dob  height_cm  \
# 13576    L. Watkowiak     Lukas Watkowiak   23  1996-03-06        197
# ...

# %%
# Show only name and wages and short them in descending order
germany[['short_name', 'wage_eur']].sort_values(by = 'wage_eur', ascending = False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %% [markdown]
# Ask student to make a variable which contains values of name and shooting capabilties and then sort them in descending order.

# %%
shooting_capability = fifa[['short_name', 'shooting']].sort_values(by = 'shooting', ascending = False)
shooting_capability
# Out:
#                short_name  shooting
# 1       Cristiano Ronaldo      93.0
# 0                L. Messi      92.0
# 12                H. Kane      91.0
# 17              S. Agüero      90.0
# 205       F. Quagliarella      89.0
# ...                   ...       ...
# 18231         P. Królczyk       NaN
# 18239          V. Storsve       NaN
# 18251  G. Sykes-Kenworthy       NaN
# 18259          H. Sveijer       NaN
# 18272           P. Martin       NaN
#
# [18278 rows x 2 columns]

# %% [markdown]
# make a variable which contains values of name, nationality, club and defending capabilties and then sort them in descending order on basis of defending capabilities.

# %%
defending_capability = fifa[['short_name', 'nationality', 'club', 'defending']].sort_values(by = 'defending', ascending = False)
defending_capability
# Out:
#                short_name          nationality               club  defending
# 16           G. Chiellini                Italy           Juventus       90.0
# 7             V. van Dijk          Netherlands          Liverpool       90.0
# 11           K. Koulibaly              Senegal             Napoli       89.0
# 35               D. Godín              Uruguay              Inter       89.0
# 49             M. Hummels              Germany  Borussia Dortmund       89.0
# ...                   ...                  ...                ...        ...
# 18231         P. Królczyk               Poland      Piast Gliwice        NaN
# 18239          V. Storsve               Norway      Lillestrøm SK        NaN
# 18251  G. Sykes-Kenworthy              England      Bradford City        NaN
# 18259          H. Sveijer               Sweden          IK Sirius        NaN
# 18272           P. Martin  Republic of Ireland       Waterford FC        NaN
#
# [18278 rows x 4 columns]

# %% [markdown]
#  find out the top 5 people who earn maximum from their favourite footaball club. Here it is real madrid.

# %%
real_madrid = fifa[fifa['club'] == 'Real Madrid']
real_madrid[['short_name', 'wage_eur']].sort_values(by = 'wage_eur', ascending = False).head()
# Out:
#       short_name  wage_eur
# 4      E. Hazard    470000
# 8      L. Modrić    340000
# 36      T. Kroos    330000
# 18  Sergio Ramos    300000
# 46    K. Benzema    285000

# %% [markdown]
# Sort in descending order on basis of shooting capabilties in real madrid.

# %%
real_madrid[['short_name', 'shooting']].sort_values(by = 'shooting', ascending = False).head()
# Out:
#        short_name  shooting
# 100       G. Bale      87.0
# 106  J. Rodríguez      86.0
# 4       E. Hazard      83.0
# 46     K. Benzema      82.0
# 161      L. Jović      82.0

# %% [markdown]
# finding player's nationality in real madrid on basis of numbers

# %%
real_madrid['nationality'].value_counts()
# Out:
# nationality
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: count, dtype: int64
